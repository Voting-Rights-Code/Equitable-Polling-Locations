# %%
import pandas as pd
import geopandas as gpd

# %%
county = 'Loudon_County'
county_st = county+'_VA'
file_name = 'tl_2020_51107_tabblock20.shp'
df_in = gpd.read_file(county_st+'/'+file_name)

# %%
df_in.head()
# Out:
#   STATEFP20 COUNTYFP20 TRACTCE20 BLOCKCE20          GEOID20      NAME20  \
# 0        51        107    610701      1019  511076107011019  Block 1019
# 1        51        107    610701      2030  511076107012030  Block 2030
# 2        51        107    610701      1041  511076107011041  Block 1041
# 3        51        107    610702      3020  511076107023020  Block 3020
# 4        51        107    610701      2031  511076107012031  Block 2031
#
#   MTFCC20  UR20 UACE20 UATYPE20 FUNCSTAT20  ALAND20  AWATER20   INTPTLAT20  \
# 0   G5040  None   None     None          S        0     12902  +39.1098176
# 1   G5040  None   None     None          S    22877         0  +39.1297691
# 2   G5040  None   None     None          S    59880      6926  +39.1169380
# 3   G5040  None   None     None          S  1610920      4018  +39.1180897
# 4   G5040  None   None     None          S    78519         0  +39.1276762
#
#      INTPTLON20                                           geometry
# ...

# %%
df = (
    df_in
    .rename(columns={'GEOID20':'id','INTPTLAT20':'lat','INTPTLON20':'lon'})
    [['id','lat','lon']]
)
df.head()
# Out:
#                 id          lat           lon
# 0  511076107011019  +39.1098176  -077.7376899
# 1  511076107012030  +39.1297691  -077.7151018
# 2  511076107011041  +39.1169380  -077.7114599
# 3  511076107023020  +39.1180897  -077.7050371
# 4  511076107012031  +39.1276762  -077.7156149

# %%
voting_data_dir = '/Users/daphneskipper/Documents/git/voting_data/data/VA/'
df.to_csv(voting_data_dir+county+'/census_blocks.csv')
